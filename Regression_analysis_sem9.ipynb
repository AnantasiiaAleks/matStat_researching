# %% [markdown]
# <a href="https://colab.research.google.com/github/AnantasiiaAleks/matStat_researching/blob/main/Regression_analysis_sem9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Постройте графики для приведенных наборов данных. Найдите коэффициенты для линии регрессии и коэффициенты детерминации.
# Что вы замечаете? Нанесите на график модель линейной регрессии.
# ```python
# X1= np.array([30,30,40, 40)]
# Y1= np.array([37, 47, 50, 60)]
# x2= np.array([30,30,40, 40, 20, 20, 50, 50])
# y2= np.array([37, 47, 50, 60, 25, 35, 62, 72])
# X3 = np.array([30,30,40, 40, 20, 20, 50, 50, 10, 10, 60, 60])
# Y3 = np.array([37, 47, 50, 60, 25, 35, 62, 72, 13, 23, 74, 84])
#
# import scipy.stats as stats
# import numpy as np
# import matplotlib.pyplot as plt
#
# plt.scatter(x, y)
# plt.title('r= вписать значение коэффициента')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.show()
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sps
from sklearn.linear_model import LinearRegression
from math import comb

# %%
X1= np.array([30, 30, 40, 40])
Y1= np.array([37, 47, 50, 60])

model1 = LinearRegression()
X1 = X1.reshape(-1, 1)
regres1 = model1.fit(X1, Y1)
print(f'b0: {regres1.intercept_=}')
print(f'b1: {regres1.coef_=}')

y_pred1 = model1.predict(X1)
print(y_pred1)

print(f'Коэффициент детерминации R^2: {regres1.score(X1, Y1)}')
# Out:
# b0: regres1.intercept_=3.0
# b1: regres1.coef_=array([1.3])
# [42. 42. 55. 55.]
# 0.6282527881040892

# %%
plt.scatter(X1, Y1)
plt.plot(X1, y_pred1)
plt.title('r^2= 0.6282527881040892')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
x2= np.array([30,30,40, 40, 20, 20, 50, 50])
y2= np.array([37, 47, 50, 60, 25, 35, 62, 72])

model2 = LinearRegression()
x2 = x2.reshape(-1, 1)
regres2 = model2.fit(x2, y2)
print(f'b0: {regres2.intercept_=}')
print(f'b1: {regres2.coef_=}')

y_pred2 = model2.predict(x2)
print(y_pred2)

print(f'Коэффициент детерминации R^2: {regres2.score(x2, y2)}')
# Out:
# b0: regres2.intercept_=5.1000000000000085
# b1: regres2.coef_=array([1.24])
# [42.3 42.3 54.7 54.7 29.9 29.9 67.1 67.1]
# Коэффициент детерминации R^2: 0.8846950517836594

# %%
plt.scatter(x2, y2)
plt.plot(x2, y_pred2)
plt.title('r^2= 0.8846950517836594')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
X3 = np.array([30,30,40, 40, 20, 20, 50, 50, 10, 10, 60, 60])
Y3 = np.array([37, 47, 50, 60, 25, 35, 62, 72, 13, 23, 74, 84])

model3 = LinearRegression()
X3 = X3.reshape(-1, 1)
regres3 = model3.fit(X3, Y3)
print(f'b0: {regres3.intercept_=}')
print(f'b1: {regres3.coef_=}')

y_pred3 = model3.predict(X3)
print(f'Предсказанные точки: {y_pred3}')

print(f'Коэффициент детерминации R^2: {regres3.score(X3, Y3)}')
# Out:
# b0: regres3.intercept_=5.600000000000016
# b1: regres3.coef_=array([1.22571429])
# Предсказанные точки: [42.37142857 42.37142857 54.62857143 54.62857143 30.11428571 30.11428571
#  66.88571429 66.88571429 17.85714286 17.85714286 79.14285714 79.14285714]
# Коэффициент детерминации R^2: 0.9459101071621309

# %%
plt.scatter(X3, Y3)
plt.plot(X3, y_pred3)
plt.title('r^2= 0.9459101071621309')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# На 8 уроке мы строили графики приведенных ниже данных.
#  Для какого графика можно использовать модель линейной регрессии?
#  x = np.array([10,8, 13, 9,11,14, 6,4,12, 7,5])
#  y = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68 ])
#
#  x= np.array([ 10,8, 13, 9,11,14, 6,4,12, 7,5 ])
#  y2 = np.array([ 9.14, 8.14, 8.74,8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])
#
#  x= np.array([ 10,8, 13, 9,11,14, 6,4,12, 7,5 ])
#  y3 = np.array([7.46,6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73])
#
#  x4 = np.array([8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8])
#  y4 = np.array([6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25,12.5, 5.56, 7.91, 6.89])
#
#  x0= np.array([ 10, 8, 13, 9, 11, 14, 6, 4, 12, 7,5,  15, 16, 18 ])
#  y0 = np.array([ 9.14, 8.14, 8.74,8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74, 6.5, 5, 2.9])

# %% [markdown]
# - x и y (первый набор):
# - Значения y меняются с небольшой линейной тенденцией. Визуально это можно считать пригодным для линейной регрессии.
#
# - x и y2 (второй набор):
# - Значения y также имеют аналогичную линейную тенденцию, хотя наблюдаются небольшие колебания. Этот график тоже может быть проанализирован с помощью линейной регрессии. Однако ниже видно, что остатки(ошибки) складываются в параболу, следовательно применение линейной регрессии невозможно.
#
# - x и y3 (третий набор):
# - Значения y имеют значительно более широкий диапазон и не демонстрируют четкой линейной зависимости. Линейная регрессия здесь может не дать хороших результатов.
#
# - x4 и y4 (четвертый набор):
# - Все значения x, кроме одного, равны, что создает ситуацию, когда независимая переменная практически не меняется. Это делает невозможным применение линейной регрессии.
#
# - x0 и y0 (пятый набор):
# - В этом наборе наблюдаются выбросы и нестабильная зависимость между переменными. Линейная связь также не является очевидной.
#
# Заключение:
# Основываясь на этом анализе, модели линейной регрессии может быть разумно применена для первого  набора данных (x и y). Остальные наборы данных (y2, y3, y4 и y0) не подходят для использования линейной регрессии из-за отсутствия линейной зависимости или других проблем, таких как выбросы или недостаток изменчивости.

# %%
# Первый набор
x4 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y4 = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68])

model4 = LinearRegression()
x4 = x4.reshape(-1, 1)
regres4 = model4.fit(x4, y4)
print(f'b0: {regres4.intercept_=}')
print(f'b1: {regres4.coef_=}')

y_pred4 = model4.predict(x4)
print(f'Предсказанные точки: {y_pred4}')

print(f'Коэффициент детерминации R^2: {regres4.score(x4, y4)}')
# Out:
# b0: regres4.intercept_=3.0000909090909094
# b1: regres4.coef_=array([0.50009091])
# Предсказанные точки: [ 8.001       7.00081818  9.50127273  7.50090909  8.50109091 10.00136364
#   6.00063636  5.00045455  9.00118182  6.50072727  5.50054545]
# Коэффициент детерминации R^2: 0.6665424595087748

# %%
plt.scatter(x4, y4)
plt.plot(x4, y_pred4)
plt.title('r^2= 0.6665424595087748')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Независимость остатков
eps4 = y4 - y_pred4

plt.scatter(x4, eps4)
plt.plot(x4, np.repeat(np.mean(eps4), len(x4)))
plt.title('Независимость остатков')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Нормальное распределение остатков
sps.shapiro(eps4)
# ShapiroResult(statistic=0.9421076645229964, pvalue=0.5455846842938527) Нет оснований отвергать нулевую гипотезу. Распределены нормально
# Out:
# ShapiroResult(statistic=0.9421076645229964, pvalue=0.5455846842938527)

# %%
# Второй набор
x5 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y5 = np.array([9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])

model5 = LinearRegression()
x5 = x5.reshape(-1, 1)
regres5 = model5.fit(x5, y5)
print(f'b0: {regres5.intercept_=}')
print(f'b1: {regres5.coef_=}')

y_pred5 = model5.predict(x5)
print(f'Предсказанные точки: {y_pred5}')

print(f'Коэффициент детерминации R^2: {regres5.score(x5, y5)}')
# Out:
# b0: regres5.intercept_=3.00090909090909
# b1: regres5.coef_=array([0.5])
# Предсказанные точки: [ 8.00090909  7.00090909  9.50090909  7.50090909  8.50090909 10.00090909
#   6.00090909  5.00090909  9.00090909  6.50090909  5.50090909]
# Коэффициент детерминации R^2: 0.6662420337274844

# %%
plt.scatter(x5, y5)
plt.plot(x5, y_pred5)
plt.title('r^2= 0.6662420337274844')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Независимость остатков
eps5 = y5 - y_pred5

plt.scatter(x5, eps5)
plt.plot(x5, np.repeat(np.mean(eps5), len(x5)))
plt.title('r^2= 0.6662420337274844')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# На графике явно видно, что остатки(ошибки) складываются в параболу. Следовательно, линейную регрессию применить нельзя

# %% [markdown]
# Какой должна быть численность групп, чтобы с вероятностью 90% обнаруживать снижение летальности с 90 до 30%. Уровень значимости α = 0,05. При решении вам пригодятся табличные значения стандартного нормального распределения

# %%
# H0: p0 = 90 %
# H1: p1 = 30 %

alpha = 0.05
beta = 1 - 0.9

# z-значения:
z_crit = 1.96
z_beta = 1.28

# Данные вероятностей летальности:
p0 = 0.9
p1 = 0.3

# расчетчисла наблюдений:
n = ((z_crit + z_beta)**2) * ((p0 * (1 - p0)) + (p1 * (1 - p1))) / ((p0 - p1) ** 2)  # 8.748 -> не менее 9 человек
# Out:
# 8.748

# %% [markdown]
# Из 10 билетов выигрышными являются 2. Чему равна вероятность того, что среди взятых наудачу 5 билетов два  выигрышных?

# %%
tickets = 10
win_tickets = 2
lose_tickets = 8
taken = 5
taken_win = 2
taken_lose = 5


C_taken_from_all = comb(tickets, taken)     # 252
C_taken_lose = comb(lose_tickets, taken_lose)   # 56
C_taken_win = comb(win_tickets, taken_win)    # 1
C_good = C_taken_win * C_taken_lose           # 56
P = C_good / C_taken_from_all
print(f'Вероятность составляет: {P*100 : .2f}%')
# Out:
# Вероятность составляет:  22.22%

# %% [markdown]
# Какова вероятность наступления события В в каждом отдельном испытании, если наивероятнейшее число наступления события В в 120 испытаниях составило 32?

# %%
n = 120
k0 = 32

# np - q <= k0 <= np + q
# q = 1 - p
# 120 * p - (1 - p) <= 32 <= 120 * p + (1 - p)
# 121p <= 33
# 119p >= 31
# 0.26 <= p <= 0.27

# %% [markdown]
# # Домашка

# %% [markdown]
# **Задание 1.**
# Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks):
# zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110]
# ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832].
# Используя математические операции, посчитать коэффициенты линейной регрессии, приняв за X заработную плату (то есть, zp- признак), а за Y - значения скорингового балла (то есть, ks- целевая переменная). Произвести расчет как с использованием intercept, так и без.

# %% [markdown]
#  Подсказка № 1
#  Ковариация между двумя переменными помогает определить, насколько они
#  изменяются вместе. В Python ковариацию между zp и ks можно найти через формулу:
#  Cov(X,Y)= ∑(𝑋−𝑋¯)⋅(𝑌−𝑌¯) / 𝑛−1
#  , где X и Y —переменные, а Xˉ и Yˉ — их средние значения.
#
#  Подсказка № 2
#  Рассчитать коэффициент наклона без intercept. Для получения коэффициента наклона
#  (b) без intercept используйте формулу:
#  b= 𝐶𝑜𝑣(𝑋,𝑌) /  𝑉𝑎𝑟(𝑋)
# Дисперсию (Var) можно найти как
#  ∑(𝑋−𝑋¯) ** 2 /  𝑛−1
# В Python это делается через np.sum и np.mean.
#
#  Подсказка № 3
#  При расчете коэффициентов с intercept, формула для intercept (a) следующая:
#  a=Yˉ−b⋅Xˉ. Это значение добавляет смещение к регрессионной линии, чтобы она
#  проходила через средние значения переменных.

# %%
import numpy as np
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

zp_mean = np.mean(zp)
ks_mean = np.mean(ks)

n = len(zp)             # = len(ks)

# Ковариация и дисперсия
Cov_zp_ks = np.sum((zp - zp_mean) * (ks - ks_mean)) / (n - 1)       # 10175.37777777778
Var_zp = np.sum((zp - zp_mean)**2) / (n - 1)                        # 3882.9333333333334

# Без intercept
b = Cov_zp_ks / Var_zp                                              # 2.620538882402766

# Интерсепт
a = ks_mean - b * zp_mean                                           # 444.1773573243595
# Out:
# 444.1773573243595

# %% [markdown]
#  **Задача 2.**
# Посчитать коэффициент линейной регрессии при заработной плате (zp), используя градиентный спуск (без intercept).

# %% [markdown]
# Подсказка № 1
# Градиентный спуск — это метод оптимизации, который помогает находить значения параметров, минимизирующие функцию потерь. В этом случае, функция потерь — это среднеквадратичная ошибка. Градиентный спуск обновляет коэффициенты на основе градиента функции потерь относительно этих коэффициентов.
# Подсказка № 2
# Градиент для линейной регрессии с одной переменной (без intercept) вычисляется как
# 1/𝑛 * ∑(y−(b⋅x))⋅x, где b — текущий коэффициент наклона.
# Подсказка № 3
# Скорость обучения определяет, насколько большие шаги делаются при обновлении коэффициента наклона. Выберите скорость обучения так, чтобы градиентный спуск сходился, но не прыгал вокруг оптимального значения. Если скорость обучения слишком велика, алгоритм может не сойтись.
# Подсказка № 4
# Количество итераций должно быть достаточным, чтобы алгоритм успел сойтись. При небольшом числе итераций может не хватить времени для нахождения оптимального решения. Следите за значением MSE и,если необходимо, увеличьте число итераций.
# Подсказка № 5
# Среднеквадратичная ошибка (MSE) вычисляется как
# 1/n * ∑(𝑦−𝑦^)**2 ,где 𝑦^ предсказанные значения.
# Это значение помогает отслеживать, насколько хорошо модель подгоняет данные на каждом шаге градиентного спуска.
# Подсказк а№ 6
# На каждом шаге градиентного спуска важно выводить текущие значения коэффициента и MSE. Это позволит увидеть, как меняется ошибка и как быстро сходится модель.

# %%
import numpy as np
from math import e

zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

alpha = 0.000001
b = 0.1
n = len(zp)             # = len(ks)
iterations = 1000

def mse(b, x=zp, y=ks, n=10):
  return (np.sum(b* x - y)**2) / n

for i in range(iterations):
  b -= alpha * (2/n) * np.sum((b * zp - ks) * zp)
  if i % 100 == 0:
    print(f'{i}: {b=}, mse= {mse(b)}')

print(f'Коэффициент склонности: {b: .3f}')          # Коэффициент склонности:  5.890
# Out:
# 0: b=0.25952808, mse= 4672868.836557692
# 100: b=5.54537842245223, mse= 217853.54976661596
# 200: b=5.868748638669329, mse= 131810.8077273557
# 300: b=5.888531320728348, mse= 127244.99680579857
# 400: b=5.8897415574471985, mse= 126968.28841071585
# 500: b=5.889815595583751, mse= 126951.37011565862
# 600: b=5.889820124983314, mse= 126950.33514891358
# 700: b=5.889820402076462, mse= 126950.2718333306
# 800: b=5.88982041902807, mse= 126950.26795990097
# 900: b=5.889820420065112, mse= 126950.26772293777
# Коэффициент склонности:  5.890

# %% [markdown]
# **Задача 3.**
#  Произвести вычисления как в пункте 2, но с вычислением intercept. Учесть, что изменение коэффициентов должно производиться на каждом шаге одновременно (то есть изменение одного коэффициента не должно влиять на изменение другого во время одной итерации).

# %% [markdown]
# Подсказка № 1
# Градиентный спуск требует вычисления градиента функции потерь для каждого параметра. Убедитесь, что расчет градиента для коэффициента наклона (w) и intercept (b) производится отдельно, но обновление этих параметров происходит одновременно в каждом шаге.
#
# Подсказка № 2
# Градиент для w (наклона) и b (intercept) следует вычислять отдельно.
# Формула для w —
#  (2 / 𝑛) * ∑(ypred−y)⋅x
# а для b —
#  (2 / 𝑛) * ∑(ypred−y).
# Убедитесь, что градиенты правильно рассчитываются и используются для обновления коэффициентов.
#
# Подсказка № 3
# После вычисления градиентов для обоих параметров, обновите их одновременно, но не пересчитывайте их до следующего шага. Это важно для правильного выполнения градиентного спуска, чтобы изменения в одном параметре не влияли на изменения в другом на одном шаге.
#
# Подсказка № 4
# Скорость обучения (alfa) контролирует, насколько быстро коэффициенты обновляются. Небольшое значение скорости обучения может замедлить процесс, а слишком большое значение может привести к расходимости. Подберите значение alfa так, чтобы градиентный спуск стабильно сходился.
#
# Подсказка № 5
# На каждом шаге полезно вычислять и отслеживать среднеквадратичную ошибку (MSE). Это позволяет вам увидеть, как меняется качество модели и помогает понять, сходится ли алгоритм.Вывод значений MSE периодически, например, каждые 10 итераций, поможет вам следить за прогрессом.
#
# Подсказка № 6
# Начальные значения коэффициентов (например, w и b) могутбыть любыми, но их правильная инициализация важна для стабильности обучения. Обычно инициализация производится нулями или малыми случайными числами.

# %%
import numpy as np

zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

alpha = 0.000001
w = 0
b = 0

n = len(zp)             # = len(ks)
iterations = 5000

def mse(w, x=zp, y=ks, n=10):
  return np.mean((w * x - y) ** 2)

for i in range(iterations):
  y_pred = w * zp + b                                   # формула линейной регрессии для каждой предсказанной точки
  w -= alpha * (2 / n) * np.sum((y_pred - ks) * zp)     # формула из подсказок
  b -= alpha * (2 / n) * np.sum(y_pred - ks)            # формула из подсказок
  # y_errors = y_pred - ks                                # Ошибки в точке, разница предсказанной и фактической
  # w -= alpha * (2 / n) * np.dot(zp, y_errors)           # вариант из решения
  # b -= alpha * (2 / n) * np.sum(y_errors)               № вариант из решения
  if i % 500 == 0 or i > 4995:
    print(f'{i}: {w=}, {b=}, mse= {mse(w)}')


print(f'Коэффициент склонности: {w: .3f}, интерсепт: {b: .3f}')

# 1) Коэффициент склонности:  5.881, интерсепт:  1.168
# 2) Коэффициент склонности:  5.881, интерсепт:  1.168
# Out:
# 0: w=0.1622834, b=0.0014198, mse= 508453.81727076985
# 500: w=5.888725892552282, b=0.15621584605168118, mse= 56516.87491995704
# 1000: w=5.887901920655762, b=0.2688281093541196, mse= 56516.90912242779
# 1500: w=5.88707325509769, b=0.3814117759539384, mse= 56516.96238655863
# 2000: w=5.8862447997008, b=0.4939668891893482, mse= 56517.03455039731
# 2500: w=5.885416554416, b=0.6064934563020581, mse= 56517.12559955788
# 3000: w=5.884588519189991, b=0.7189914845319078, mse= 56517.23551966333
# 3500: w=5.883760693969505, b=0.8314609811169043, mse= 56517.364296345026
# 4000: w=5.882933078701277, b=0.9439019532932161, mse= 56517.51191524287
# 4500: w=5.882105673332061, b=1.056314408295177, mse= 56517.678362005274
# 4996: w=5.881285094540282, b=1.1677993949032028, mse= 56517.86206559265
# 4997: w=5.881283440356109, b=1.1680241346872402, mse= 56517.862454653994
# 4998: w=5.881281786172774, b=1.1682488743572665, mse= 56517.862843790535
# ...
